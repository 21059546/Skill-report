# %%
import simpy
import random
import statistics

# %% [markdown]
# Line up for tickets

# %%
wait_times = []

# %%
# Environment
class Ticket_Counts(object):
    def __init__(self, env, num_cashiers, num_servers, num_ushers):
        self.env = env
        self.cashier = simpy.Resource(env, num_cashiers)
        self.servers = simpy.Resource(env, num_servers)
        self.ushers = simpy.Resource(env, num_ushers)
        
    
        
    def purchase_ticket(self, buyers):
        yield self.env.timeout(random.randint(2, 4))
        # Set ticket buying time
        
    def check_ticket(self, buyers):
        yield self.env.timeout(random.randint(0, 1))
        # Set ticket buying time
        
    def other_sell(self, buyers):
        yield self.env.timeout(random.randint(5, 10))
        # Set ticket buying time

# %%
    # Process 
    def go_to_sites(env, buyer, counts):
        # buyer arrives at the ticket counts
        arrival_time = env.now

        # buy tickets
        with counts.cashier.request() as request:
            yield request
            yield env.process(counts.purchase_ticket(buyer))
            print('after buy tickets: %d' %int(env.now))


        # check tickets
        with counts.ushers.request() as request:
            yield request
            yield env.process(counts.check_ticket(buyer))
            print('after check tickets: %d'%int(env.now))
            print('----------------------------------')

        # other random behaviors
        if random.choice([True, False]):
            with counts.servers.request() as request:
                yield request
                yield env.process(counts.other_sell(buyer))
                print('after other random behaviors: %d'%int(env.now))
                print('----------------------------------')


        # buyer heads into the site
        wait_times.append(env.now - arrival_time)

# %%
    # Run
    def run(env, num_cashiers, num_servers, num_ushers):
        ticket_counts = Ticket_Counts(env, num_cashiers, num_servers, num_ushers)
    
        for buyer in range(3):
            env.process(go_to_sites(env, buyer, ticket_counts))

        while True:
            yield env.timeout(0.50)  
            # Wait a bit before generating a new person
            buyer += 1
            env.process(go_to_sites(env, buyer, ticket_counts))

# %%
    # Calculation
    def get_average_wait_time(wait_times):
        average_wait = statistics.mean(wait_times)

        minutes, frac_minutes = divmod(average_wait, 1)
        seconds = frac_minutes * 60
        return round(minutes), round(seconds)

# %%
    # Define number of workers
    def get_user_input():
        num_cashiers = input("Number of cashiers working: ")
        num_servers = input("Number of servers working: ")
        num_ushers = input("Number of ushers working: ")
        params = [num_cashiers, num_servers, num_ushers]

        # Check input is valid
        if all(str(i).isdigit() for i in params):  
            params = [int(x) for x in params]
        else:
            print("Could not parse input. The simulation will use default values:","\n1 cashier, 1 server, 1 usher.",)
            params = [1, 1, 1]
        return params

# %%
    # Define function
    def main():
        # Setup
        random.seed(5)
        num_cashiers, num_servers, num_ushers = get_user_input()

        # Run the simulation
        env = simpy.Environment()
        env.process(run(env, num_cashiers, num_servers, num_ushers))
        env.run(until=100)

        # View the results
        mins, secs = get_average_wait_time(wait_times)
        print("Running simulation...",f"\nThe average wait time is {mins} minutes and {secs} seconds.",)

# %%
 if __name__ == '__main__':
    main()
# Out:
# Number of cashiers working: 5
# Number of servers working: 2
# Number of ushers working: 10
# after buy tickets: 3
# after check tickets: 3
# ----------------------------------
# after buy tickets: 3
# after check tickets: 3
# ----------------------------------
# after buy tickets: 4
# after buy tickets: 4
# after check tickets: 4
# ----------------------------------
# after buy tickets: 5
# after check tickets: 5
# ----------------------------------
# after check tickets: 5
# ----------------------------------
# after buy tickets: 5
# after buy tickets: 6
# after check tickets: 6
# ----------------------------------
# after check tickets: 6
# ----------------------------------
# after buy tickets: 7
# after check tickets: 7
# ----------------------------------
# after buy tickets: 8
# after check tickets: 8
# ----------------------------------
# after buy tickets: 8
# after check tickets: 8
# ----------------------------------
# after buy tickets: 9
# after buy tickets: 9
# after check tickets: 9
# ----------------------------------
# after check tickets: 9
# ----------------------------------
# after buy tickets: 10
# after check tickets: 10
# ----------------------------------
# after other random behaviors: 10
# ----------------------------------
# after buy tickets: 10
# after buy tickets: 11
# after check tickets: 11
# ----------------------------------
# after buy tickets: 12
# after buy tickets: 12
# after check tickets: 12
# ----------------------------------
# after check tickets: 12
# ----------------------------------
# after buy tickets: 12
# after other random behaviors: 13
# ----------------------------------
# after check tickets: 13
# ----------------------------------
# after check tickets: 13
# ----------------------------------
# after buy tickets: 14
# after buy tickets: 14
# after buy tickets: 14
# after buy tickets: 15
# after buy tickets: 15
# after check tickets: 15
# ----------------------------------
# after check tickets: 15
# ----------------------------------
# after check tickets: 15
# ----------------------------------
# after check tickets: 15
# ----------------------------------
# after buy tickets: 16
# after check tickets: 16
# ----------------------------------
# after buy tickets: 17
# after check tickets: 17
# ----------------------------------
# after other random behaviors: 17
# ----------------------------------
# after buy tickets: 18
# after check tickets: 18
# ----------------------------------
# after check tickets: 18
# ----------------------------------
# after buy tickets: 18
# after buy tickets: 19
# after buy tickets: 19
# after buy tickets: 19
# after check tickets: 19
# ----------------------------------
# after other random behaviors: 20
# ----------------------------------
# after buy tickets: 20
# after check tickets: 20
# ----------------------------------
# after check tickets: 20
# ----------------------------------
# after check tickets: 20
# ----------------------------------
# after check tickets: 20
# ----------------------------------
# after buy tickets: 21
# after check tickets: 21
# ----------------------------------
# after buy tickets: 21
# after check tickets: 21
# ----------------------------------
# after buy tickets: 23
# after buy tickets: 23
# after buy tickets: 23
# after check tickets: 23
# ----------------------------------
# after check tickets: 23
# ----------------------------------
# after buy tickets: 24
# after check tickets: 24
# ----------------------------------
# after check tickets: 24
# ----------------------------------
# after buy tickets: 24
# after check tickets: 24
# ----------------------------------
# after buy tickets: 25
# after other random behaviors: 26
# ----------------------------------
# after buy tickets: 26
# after check tickets: 26
# ----------------------------------
# after check tickets: 26
# ----------------------------------
# after buy tickets: 26
# after buy tickets: 27
# after buy tickets: 27
# after check tickets: 27
# ----------------------------------
# after check tickets: 27
# ----------------------------------
# after other random behaviors: 27
# ----------------------------------
# after check tickets: 27
# ----------------------------------
# after buy tickets: 28
# after check tickets: 29
# ----------------------------------
# after buy tickets: 29
# after check tickets: 29
# ----------------------------------
# after buy tickets: 30
# after check tickets: 30
# ----------------------------------
# after other random behaviors: 31
# ----------------------------------
# after buy tickets: 31
# after buy tickets: 31
# after buy tickets: 31
# after check tickets: 32
# ----------------------------------
# after check tickets: 32
# ----------------------------------
# after check tickets: 32
# ----------------------------------
# after buy tickets: 32
# after buy tickets: 33
# after check tickets: 33
# ----------------------------------
# after other random behaviors: 33
# ----------------------------------
# after check tickets: 33
# ----------------------------------
# after buy tickets: 34
# after buy tickets: 34
# after buy tickets: 34
# after check tickets: 34
# ----------------------------------
# after check tickets: 35
# ----------------------------------
# after check tickets: 35
# ----------------------------------
# after buy tickets: 36
# after check tickets: 36
# ----------------------------------
# after buy tickets: 37
# after buy tickets: 38
# after buy tickets: 38
# after buy tickets: 38
# after check tickets: 38
# ----------------------------------
# after check tickets: 38
# ----------------------------------
# after other random behaviors: 39
# ----------------------------------
# after check tickets: 39
# ----------------------------------
# after check tickets: 39
# ----------------------------------
# after other random behaviors: 39
# ----------------------------------
# after buy tickets: 39
# after buy tickets: 40
# after buy tickets: 40
# after check tickets: 40
# ----------------------------------
# after buy tickets: 41
# after check tickets: 41
# ----------------------------------
# after check tickets: 41
# ----------------------------------
# after check tickets: 41
# ----------------------------------
# after buy tickets: 42
# after buy tickets: 43
# after check tickets: 43
# ----------------------------------
# after check tickets: 43
# ----------------------------------
# after buy tickets: 43
# after buy tickets: 44
# after check tickets: 44
# ----------------------------------
# after check tickets: 44
# ----------------------------------
# after buy tickets: 45
# after buy tickets: 45
# after buy tickets: 45
# after check tickets: 46
# ----------------------------------
# after check tickets: 46
# ----------------------------------
# after check tickets: 46
# ----------------------------------
# after buy tickets: 46
# after check tickets: 46
# ----------------------------------
# after other random behaviors: 47
# ----------------------------------
# after buy tickets: 47
# after buy tickets: 47
# after check tickets: 47
# ----------------------------------
# after buy tickets: 48
# after check tickets: 48
# ----------------------------------
# after other random behaviors: 48
# ----------------------------------
# after buy tickets: 49
# after buy tickets: 49
# after buy tickets: 49
# after check tickets: 49
# ----------------------------------
# after check tickets: 49
# ----------------------------------
# after buy tickets: 50
# after check tickets: 50
# ----------------------------------
# after check tickets: 50
# ----------------------------------
# after buy tickets: 50
# after check tickets: 51
# ----------------------------------
# after check tickets: 51
# ----------------------------------
# after buy tickets: 52
# after buy tickets: 52
# after buy tickets: 52
# after check tickets: 52
# ----------------------------------
# after check tickets: 52
# ----------------------------------
# after other random behaviors: 53
# ----------------------------------
# after buy tickets: 53
# after check tickets: 53
# ----------------------------------
# after buy tickets: 53
# after check tickets: 54
# ----------------------------------
# after check tickets: 54
# ----------------------------------
# after buy tickets: 55
# after buy tickets: 55
# after check tickets: 55
# ----------------------------------
# after check tickets: 55
# ----------------------------------
# after buy tickets: 56
# after buy tickets: 56
# after check tickets: 56
# ----------------------------------
# after check tickets: 56
# ----------------------------------
# after other random behaviors: 56
# ----------------------------------
# after buy tickets: 56
# after check tickets: 56
# ----------------------------------
# after buy tickets: 58
# after buy tickets: 59
# after buy tickets: 59
# after check tickets: 59
# ----------------------------------
# after other random behaviors: 60
# ----------------------------------
# after buy tickets: 60
# after check tickets: 60
# ----------------------------------
# after check tickets: 60
# ----------------------------------
# after buy tickets: 60
# after buy tickets: 61
# after check tickets: 61
# ----------------------------------
# after check tickets: 61
# ----------------------------------
# after buy tickets: 62
# after buy tickets: 62
# after buy tickets: 62
# after check tickets: 62
# ----------------------------------
# after check tickets: 63
# ----------------------------------
# after check tickets: 63
# ----------------------------------
# after check tickets: 63
# ----------------------------------
# after other random behaviors: 63
# ----------------------------------
# after buy tickets: 64
# after buy tickets: 64
# after check tickets: 64
# ----------------------------------
# after buy tickets: 64
# after buy tickets: 65
# after buy tickets: 65
# after check tickets: 65
# ----------------------------------
# after check tickets: 65
# ----------------------------------
# after check tickets: 65
# ----------------------------------
# after buy tickets: 66
# after check tickets: 66
# ----------------------------------
# after buy tickets: 67
# after buy tickets: 67
# after buy tickets: 67
# after check tickets: 67
# ----------------------------------
# after check tickets: 67
# ----------------------------------
# after check tickets: 67
# ----------------------------------
# after other random behaviors: 68
# ----------------------------------
# after check tickets: 68
# ----------------------------------
# after buy tickets: 68
# after buy tickets: 69
# after buy tickets: 69
# after check tickets: 69
# ----------------------------------
# after check tickets: 69
# ----------------------------------
# after other random behaviors: 69
# ----------------------------------
# after check tickets: 69
# ----------------------------------
# after buy tickets: 70
# after buy tickets: 70
# after buy tickets: 71
# after check tickets: 71
# ----------------------------------
# after check tickets: 71
# ----------------------------------
# after buy tickets: 71
# after check tickets: 71
# ----------------------------------
# after buy tickets: 72
# after check tickets: 72
# ----------------------------------
# after check tickets: 73
# ----------------------------------
# after buy tickets: 74
# after buy tickets: 74
# after buy tickets: 74
# after buy tickets: 74
# after check tickets: 74
# ----------------------------------
# after other random behaviors: 74
# ----------------------------------
# after buy tickets: 74
# after check tickets: 75
# ----------------------------------
# after check tickets: 75
# ----------------------------------
# after check tickets: 75
# ----------------------------------
# after check tickets: 75
# ----------------------------------
# after other random behaviors: 76
# ----------------------------------
# after buy tickets: 76
# after buy tickets: 76
# after check tickets: 76
# ----------------------------------
# after buy tickets: 77
# after check tickets: 77
# ----------------------------------
# after buy tickets: 78
# after buy tickets: 78
# after buy tickets: 78
# after check tickets: 78
# ----------------------------------
# after check tickets: 78
# ----------------------------------
# after check tickets: 78
# ----------------------------------
# after check tickets: 78
# ----------------------------------
# after buy tickets: 79
# after buy tickets: 80
# after check tickets: 80
# ----------------------------------
# after check tickets: 80
# ----------------------------------
# after other random behaviors: 81
# ----------------------------------
# after buy tickets: 81
# after check tickets: 81
# ----------------------------------
# after buy tickets: 81
# after check tickets: 81
# ----------------------------------
# after buy tickets: 82
# after buy tickets: 82
# after check tickets: 82
# ----------------------------------
# after check tickets: 83
# ----------------------------------
# after other random behaviors: 83
# ----------------------------------
# after buy tickets: 84
# after buy tickets: 84
# after check tickets: 84
# ----------------------------------
# after check tickets: 84
# ----------------------------------
# after buy tickets: 85
# after buy tickets: 85
# after buy tickets: 85
# after check tickets: 85
# ----------------------------------
# after other random behaviors: 86
# ----------------------------------
# after buy tickets: 86
# after check tickets: 86
# ----------------------------------
# after check tickets: 86
# ----------------------------------
# after check tickets: 86
# ----------------------------------
# after buy tickets: 87
# after buy tickets: 87
# after check tickets: 87
# ----------------------------------
# after buy tickets: 88
# after buy tickets: 88
# after check tickets: 88
# ----------------------------------
# after check tickets: 88
# ----------------------------------
# after buy tickets: 89
# after check tickets: 89
# ----------------------------------
# after check tickets: 89
# ----------------------------------
# after buy tickets: 89
# after check tickets: 89
# ----------------------------------
# after buy tickets: 90
# after buy tickets: 90
# after check tickets: 90
# ----------------------------------
# after check tickets: 91
# ----------------------------------
# after buy tickets: 91
# after check tickets: 91
# ----------------------------------
# after buy tickets: 92
# after check tickets: 92
# ----------------------------------
# after other random behaviors: 92
# ----------------------------------
# after other random behaviors: 93
# ----------------------------------
# after buy tickets: 93
# after buy tickets: 93
# after buy tickets: 93
# after check tickets: 93
# ----------------------------------
# after check tickets: 93
# ----------------------------------
# after check tickets: 93
# ----------------------------------
# after buy tickets: 94
# after buy tickets: 95
# after buy tickets: 95
# after check tickets: 95
# ----------------------------------
# after buy tickets: 95
# after buy tickets: 96
# after check tickets: 96
# ----------------------------------
# after check tickets: 96
# ----------------------------------
# after check tickets: 96
# ----------------------------------
# after buy tickets: 97
# after buy tickets: 97
# after check tickets: 97
# ----------------------------------
# after check tickets: 97
# ----------------------------------
# after check tickets: 98
# ----------------------------------
# after buy tickets: 99
# after buy tickets: 99
# after buy tickets: 99
# after check tickets: 99
# ----------------------------------
# after check tickets: 99
# ----------------------------------
# after check tickets: 99
# ----------------------------------
# after buy tickets: 99
# Running simulation...
# The average wait time is 20 minutes and 56 seconds.
